# %% [markdown]
# ## Default
# 1             |  2
# :-------------------------:|:-------------------------:
# ![](attachment:Screenshot%20from%202019-11-17%2020-28-39.png) | ![](attachment:Screenshot%20from%202019-11-17%2020-13-21.png)

# %% [markdown]
# ## First
# 1 | 2
# :-------------------------:|:-------------------------:
# ![](attachment:Screenshot%20from%202019-11-17%2020-21-39.png) | ![](attachment:Screenshot%20from%202019-11-17%2020-13-21.png)

# %% [markdown]
# ![](attachment:Screenshot%20from%202019-11-17%2020-13-21.png)

# %% [markdown]
# ## First
# 1 | 2
# :-------------------------:|:-------------------------:
# ![](![Screenshot%20from%202019-11-17%2020-28-39.png](attachment:Screenshot%20from%202019-11-17%2020-28-39.png)) | ![](attachment:Screenshot%20from%202019-11-17%2020-13-21.png)
